# %% [markdown]
# Packages

# %%
from pyomo.environ import *
import numpy as np
import random
import pandas as pd
from numpy import flatnonzero as find
from pypower.api import case39, ext2int, bustypes, makeBdc, rundcpf, ppoption, rundcopf, case30, case9, case118, case300
from pypower.idx_bus import BUS_TYPE, REF, VA, PD, LAM_P, LAM_Q, MU_VMAX, MU_VMIN
from pypower.idx_gen import PG, MU_PMAX, MU_PMIN, MU_QMAX, MU_QMIN, PMAX, PMIN, GEN_BUS
from pypower.idx_brch import PF, PT, QF, QT, RATE_A, MU_SF, MU_ST
from pypower.idx_cost import COST
import matplotlib.pyplot as plt

# %%
# Run PyPower case to get initial condition
ppc = case39()
ppopt = ppoption(VERBOSE=0)
pp_dcopf = rundcopf(ppc, ppopt)
pp_bus = pp_dcopf["bus"]
pp_branch = pp_dcopf["branch"]
pp_gen = pp_dcopf["gen"]
# Out:
# Converged in 0.04 seconds
# Objective Function Value = 41263.94 $/hr
# ================================================================================
# |     System Summary                                                           |
# ================================================================================
#
# How many?                How much?              P (MW)            Q (MVAr)
# ---------------------    -------------------  -------------  -----------------
# Buses             39     Total Gen Capacity    7367.0           0.0 to 0.0
# Generators        10     On-line Capacity      7367.0           0.0 to 0.0
# Committed Gens    10     Generation (actual)   6254.2               0.0
# Loads             21     Load                  6254.2               0.0
#   Fixed           21       Fixed               6254.2               0.0
#   Dispatchable     0       Dispatchable           0.0 of 0.0        0.0
# Shunts             0     Shunt (inj)              0.0               0.0
# Branches          46     Losses (I^2 * Z)         0.00              0.00
# Transformers      12     Branch Charging (inj)     -                0.0
# Inter-ties         6     Total Inter-tie Flow   836.0               0.0
# Areas              3
#
#                           Minimum                      Maximum
#                  -------------------------  --------------------------------
# Voltage Magnitude   0.982 p.u. @ bus 31         1.064 p.u. @ bus 36
# Voltage Angle     -18.84 deg   @ bus 39         9.01 deg   @ bus 36
# Lambda P           13.52 $/MWh @ bus 30        13.52 $/MWh @ bus 8
# Lambda Q            0.00 $/MWh @ bus 1          0.00 $/MWh @ bus 1
#
# ================================================================================
# |     Bus Data                                                                 |
# ================================================================================
#  Bus      Voltage          Generation             Load          Lambda($/MVA-hr)
#   #   Mag(pu) Ang(deg)   P (MW)   Q (MVAr)   P (MW)   Q (MVAr)     P        Q
# ----- ------- --------  --------  --------  --------  --------  -------  -------
#     1  1.039  -14.747       -         -       97.60      0.00    13.517     -
#     2  1.048   -5.726       -         -         -         -      13.517     -
#     3  1.031   -9.626       -         -      322.00      0.00    13.517     -
#     4  1.004  -11.250       -         -      500.00      0.00    13.517     -
#     5  1.006  -10.521       -         -         -         -      13.517     -
#     6  1.008   -9.760       -         -         -         -      13.517     -
#     7  0.998  -12.439       -         -      233.80      0.00    13.517     -
#     8  0.998  -13.163       -         -      522.00      0.00    13.517     -
#     9  1.038  -16.577       -         -        6.50      0.00    13.517     -
#    10  1.018   -7.022       -         -         -         -      13.517     -
#    11  1.013   -7.963       -         -         -         -      13.517     -
#    12  1.001   -7.943       -         -        8.53      0.00    13.517     -
#    13  1.015   -7.710       -         -         -         -      13.517     -
#    14  1.012   -9.272       -         -         -         -      13.517     -
#    15  1.016   -9.299       -         -      320.00      0.00    13.517     -
#    16  1.033   -7.587       -         -      329.00      0.00    13.517     -
#    17  1.034   -8.831       -         -         -         -      13.517     -
#    18  1.032   -9.594       -         -      158.00      0.00    13.517     -
#    19  1.050   -2.224       -         -         -         -      13.517     -
#    20  0.991   -3.666       -         -      680.00      0.00    13.517     -
#    21  1.032   -4.862       -         -      274.00      0.00    13.517     -
#    22  1.050    0.161       -         -         -         -      13.517     -
#    23  1.045   -0.029       -         -      247.50      0.00    13.517     -
#    24  1.038   -7.390       -         -      308.60      0.00    13.517     -
#    25  1.058   -4.873       -         -      224.00      0.00    13.517     -
#    26  1.053   -7.963       -         -      139.00      0.00    13.517     -
#    27  1.038   -9.641       -         -      281.00      0.00    13.517     -
#    28  1.050   -6.312       -         -      206.00      0.00    13.517     -
#    29  1.050   -4.003       -         -      283.50      0.00    13.517     -
#    30  1.050    1.299    660.85      0.00       -         -      13.517     -
#    31  0.982    0.000*   646.00      0.00      9.20      0.00    13.517     -
#    32  0.984    1.080    660.85      0.00       -         -      13.517     -
#    33  0.997    3.452    652.00      0.00       -         -      13.517     -
#    34  1.012    1.620    508.00      0.00       -         -      13.517     -
#    35  1.049    5.711    660.85      0.00       -         -      13.517     -
#    36  1.064    9.010    580.00      0.00       -         -      13.517     -
#    37  1.028    2.812    564.00      0.00       -         -      13.517     -
#    38  1.026    2.051    660.85      0.00       -         -      13.517     -
#    39  1.030  -18.836    660.85      0.00   1104.00      0.00    13.517     -
#                         --------  --------  --------  --------
#                Total:   6254.23      0.00   6254.23      0.00
#
# ================================================================================
# |     Branch Data                                                              |
# ================================================================================
# Brnch   From   To    From Bus Injection   To Bus Injection     Loss (I^2 * Z)
#   #     Bus    Bus    P (MW)   Q (MVAr)   P (MW)   Q (MVAr)   P (MW)   Q (MVAr)
# -----  -----  -----  --------  --------  --------  --------  --------  --------
#    0      1      2   -383.08      0.00    383.08      0.00     0.000      0.00
#    1      1     39    285.48      0.00   -285.48      0.00     0.000      0.00
#    2      2      3    450.81      0.00   -450.81      0.00     0.000      0.00
#    3      2     25   -173.05      0.00    173.05      0.00     0.000      0.00
#    4      2     30   -660.85      0.00    660.85      0.00     0.000      0.00
#    5      3      4    133.05      0.00   -133.05      0.00     0.000      0.00
#    6      3     18     -4.24      0.00      4.24      0.00     0.000      0.00
#    7      4      5    -99.32      0.00     99.32      0.00     0.000      0.00
#    8      4     14   -267.62      0.00    267.62      0.00     0.000      0.00
#    9      5      6   -510.99      0.00    510.99      0.00     0.000      0.00
#   10      5      8    411.66      0.00   -411.66      0.00     0.000      0.00
#   11      6      7    508.31      0.00   -508.31      0.00     0.000      0.00
#   12      6     11   -382.50      0.00    382.50      0.00     0.000      0.00
#   13      6     31   -636.80      0.00    636.80      0.00     0.000      0.00
#   14      7      8    274.51      0.00   -274.51      0.00     0.000      0.00
#   15      8      9    164.17      0.00   -164.17      0.00     0.000      0.00
#   16      9     39    157.67      0.00   -157.67      0.00     0.000      0.00
#   17     10     11    381.72      0.00   -381.72      0.00     0.000      0.00
#   18     10     13    279.13      0.00   -279.13      0.00     0.000      0.00
#   19     10     32   -660.85      0.00    660.85      0.00     0.000      0.00
#   20     12     11      0.78      0.00     -0.78      0.00     0.000      0.00
#   21     12     13     -9.31      0.00      9.31      0.00     0.000      0.00
#   22     13     14    269.82      0.00   -269.82      0.00     0.000      0.00
#   23     14     15      2.20      0.00     -2.20      0.00     0.000      0.00
#   24     15     16   -317.80      0.00    317.80      0.00     0.000      0.00
#   25     16     17    243.94      0.00   -243.94      0.00     0.000      0.00
#   26     16     19   -480.00      0.00    480.00      0.00     0.000      0.00
#   27     16     21   -352.29      0.00    352.29      0.00     0.000      0.00
#   28     16     24    -58.46      0.00     58.46      0.00     0.000      0.00
#   29     17     18    162.24      0.00   -162.24      0.00     0.000      0.00
#   30     17     27     81.70      0.00    -81.70      0.00     0.000      0.00
#   31     19     20    172.00      0.00   -172.00      0.00     0.000      0.00
#   32     19     33   -652.00      0.00    652.00      0.00     0.000      0.00
#   33     20     34   -508.00      0.00    508.00      0.00     0.000      0.00
#   34     21     22   -626.29      0.00    626.29      0.00     0.000      0.00
#   35     22     23     34.56      0.00    -34.56      0.00     0.000      0.00
#   36     22     35   -660.85      0.00    660.85      0.00     0.000      0.00
#   37     23     24    367.06      0.00   -367.06      0.00     0.000      0.00
#   38     23     36   -580.00      0.00    580.00      0.00     0.000      0.00
#   39     25     26    166.95      0.00   -166.95      0.00     0.000      0.00
#   40     25     37   -564.00      0.00    564.00      0.00     0.000      0.00
#   41     26     27    199.30      0.00   -199.30      0.00     0.000      0.00
#   42     26     28    -60.79      0.00     60.79      0.00     0.000      0.00
#   43     26     29   -110.56      0.00    110.56      0.00     0.000      0.00
#   44     28     29   -266.79      0.00    266.79      0.00     0.000      0.00
#   45     29     38   -660.85      0.00    660.85      0.00     0.000      0.00
#                                                              --------  --------
#                                                     Total:     0.000      0.00
#
# ================================================================================
# |     Generation Constraints                                                   |
# ================================================================================
#  Gen   Bus                Active Power Limits
#   #     #    Pmin mu    Pmin       Pg       Pmax    Pmax mu
# ----  -----  -------  --------  --------  --------  -------
#    1    31      -        0.00    646.00    646.00    0.297
#    3    33      -        0.00    652.00    652.00    0.177
#    4    34      -        0.00    508.00    508.00    3.057
#    6    36      -        0.00    580.00    580.00    1.617
#    7    37      -        0.00    564.00    564.00    1.937

# %%
## convert to internal indexing
ppc = ext2int(ppc)
baseMVA, bus, gen, branch, gencost = \
    ppc["baseMVA"], ppc["bus"], ppc["gen"], ppc["branch"], ppc["gencost"]

## get bus index lists of each type of bus
ref, pv, pq = bustypes(bus, gen)
pvpq = np.matrix(np.r_[pv, pq])

## generator info
gbus = gen[:, GEN_BUS].astype(int)    ## what buses are they at?
refgen = find(gbus == ref)

## build B matrices and phase shift injections
B, Bf, _, _ = makeBdc(baseMVA, bus, branch)
B = B.todense()
Bf = Bf.todense()

# Problem dimensions
NG = gen.shape[0] # Number of generators
NB = bus.shape[0] # Number of buses
NBr = branch.shape[0] # Number of lines
NL = np.count_nonzero(pp_bus[:, PD]) # Number of loads
NW = 1 # Number of wind farms

# Map generator to bus
CG = np.zeros((NB,NG))
CG[gbus,range(NG)] = 1

# Map load to bus
CL = np.zeros((NB,NL))
load_bus = np.nonzero(pp_bus[:, PD])[0]
for i in range(len(load_bus)):
    CL[load_bus[i], i] = 1

# Map wind farm to bus
CW = np.zeros((NB,1))
CW[5,0] = 1

# Generator capacity limit p.u.
Pmax = gen[:, PMAX]/baseMVA
Pmin = gen[:, PMIN]/baseMVA

# Line flow limit p.u.
Lmax = branch[:, RATE_A]/baseMVA
Lmin = - branch[:, RATE_A]/baseMVA

# Quadratic cost coefficients
# Convert to p.u.
CG2 = gencost[:, COST]*baseMVA**2
CG1 = gencost[:, COST+1]*baseMVA
CG0 = gencost[:, COST+2]

# Cost coefficient for wind power
CW1 = 0
CW0 = 0

# Cost coefficients for generation reserve
CRG_up = np.ones((NG,1))*10*baseMVA
CRG_down = np.ones((NG,1))*10*baseMVA

# Cost coefficients for load reserve
CRL_up = 1000*np.ones((NL,1))*baseMVA
CRL_down = 1000*np.ones((NL,1))*baseMVA

# Uncontrollable load
load = pp_bus[:,PD]
PL_total = load[load > 0]
PL = PL_total/baseMVA

# Generator and demand set points
# Power in p.u., Va in rad
Pg0 = pp_gen[:, PG]/baseMVA
Pd0 = pp_bus[:, PD]/baseMVA
Pinj0 = (np.matmul(CG, Pg0) - Pd0)
Va0 = pp_bus[:, VA]/180*np.pi

# %%
Pmax
# Out:
# array([10.4 ,  6.46,  7.25,  6.52,  5.08,  6.87,  5.8 ,  5.64,  8.65,
#        11.  ])

# %%
# Read temperature data
weather_data = pd.read_csv("Weather_Data/NYC_Hourly_Normal_Temp.csv")
# Read wind power data
PW_data = pd.read_csv("spring_wind.csv",header=None).to_numpy()
PW_data = PW_data/500*20/baseMVA

# %%
Tamb = (weather_data.iloc[:,8] - 32)/1.8
Tamb_min = min(Tamb)
Tamb_10PCTL = (weather_data.iloc[:,6] - 32)/1.8
Tamb_90PCTL = (weather_data.iloc[:,7] - 32)/1.8
std_Tamb_10PCTL = (Tamb - Tamb_10PCTL)/1.282 
std_Tamb_90PCTL = (Tamb_90PCTL - Tamb)/1.282 
std_Tamb = (std_Tamb_10PCTL + std_Tamb_90PCTL)/2

# %%
def VS(dt,Tamb,num_TCL,Tset,delta,R,C,P_el,COP,baseMVA):
    Tdown = np.zeros(num_TCL)
    Tup = np.zeros(num_TCL)
    T_ON = np.zeros(num_TCL)
    T_OFF = np.zeros(num_TCL)
    D = np.zeros(num_TCL)
    B = 0
    Pdown = 0
    Pup = 0
    Sdown = 0
    Sup = 0
    for i in range(0,num_TCL):
        Tdown[i] = Tset[i] - delta/2
        Tup[i] = Tset[i] + delta/2
        T_ON[i] = C[i]*R[i]*np.log((Tdown[i] - Tamb - R[i]*P_el[i]*COP[i])/(Tup[i] - Tamb - R[i]*P_el[i]*COP[i]))
        if ((Tdown[i] - Tamb - R[i]*P_el[i]*COP[i])/(Tup[i] - Tamb - R[i]*P_el[i]*COP[i]) < 0):
            print(Tdown[i] - Tamb - R[i]*P_el[i]*COP[i])
            print(Tup[i] - Tamb - R[i]*P_el[i]*COP[i])
        T_OFF[i] = C[i]*R[i]*np.log((Tup[i] - Tamb)/(Tdown[i] - Tamb))
        D[i] = T_ON[i]/(T_ON[i] + T_OFF[i])
        if ( Tamb < Tdown[i] and Tamb + R[i]*P_el[i]*COP[i] > Tup[i] ):
            B = B + P_el[i]*D[i]
            Pup = Pup + P_el[i]
            Sup = Sup + dt*P_el[i]*(1 - D[i])
    return [B/1000/baseMVA,Pdown/1000/baseMVA,Pup/1000/baseMVA,Sdown,Sup]

# %%
# Optimization: Problem formulation
def optimizer(NG,NL,Tamb_sample,PW_sample,PW_data,num_TCL,Tset,delta,R,C,P_el,COP,S0,PL,\
    Pmax,Pmin,Lmax,Lmin,CG,CW,CL,CG0,CG1,CG2,CW0,CW1,CRG_up,CRG_down,CRL_up,CRL_down,nsample,PW_f):
    model = ConcreteModel()
    # Defining the variables
    model.PG = Var(range(NG),within = NonNegativeReals, initialize=0)
    # model.PC = Var(range(NL),within = NonNegativeReals)
    # model.RG_down = Var(range(NG),within = NonNegativeReals, initialize=0)
    # model.RG_up = Var(range(NG),within = NonNegativeReals, initialize=0)
    # model.RG = Var(range(NG),range(nsample),within = Reals, initialize=0)
    # model.RL_down = Var(range(NL),within = NonNegativeReals)
    # model.RL_up = Var(range(NL),within = NonNegativeReals)
    # model.RL = Var(range(NL),within = NonNegativeReals)
    # model.dG_down = Var(range(NG),within = NonNegativeReals)
    # model.dG_up = Var(range(NG),within = NonNegativeReals)
    # model.dL_down = Var(range(NL),within = NonNegativeReals)
    # model.dL_up = Var(range(NL),within = NonNegativeReals)
    # model.P_mis = Var(range(nsample), within=Reals)
    model.Va = Var(range(NB), within=Reals, initialize=0, bounds=(-1,1))
    # model.y = Var(range(20), within=Binary)
    # model.a = Var(range(20), within=NonNegativeReals, initialize=0)
    # model.s1 = Var(range(nsample), within=NonNegativeReals, initialize=0)
    # model.s2 = Var(range(nsample), within=NonNegativeReals, initialize=0)

    model.dual = Suffix(direction=Suffix.IMPORT)

    ## Defining the deterministic constraints
    model.c = ConstraintList()

    

    # model.c.add(sum(model.dG_down[i] for i in range(NG)) + sum(model.dL_up[j] for j in range(NL)) == 1)
    # model.c.add(sum(model.dG_up[i] for i in range(NG)) + sum(model.dL_down[j] for j in range(NL)) == 1)
    # model.c.add(sum(model.dG_down[i] for i in range(NG)) == 1)
    # model.c.add(sum(model.dG_up[i] for i in range(NG)) == 1)
    
    # Line flow limit constraints
    for i in range(NBr):
        model.c.add(sum(Bf[i,j]*model.Va[j] for j in range(NB)) <= Lmax[i])
        model.c.add(sum(Bf[i,j]*model.Va[j] for j in range(NB)) >= Lmin[i])
    
    # i = 100
    # Defining the CC constraints
    for i in range(nsample):

        for j in range(NG):
        # Generation capacity limit
            # model.c.add(model.PG[j] + model.RG[j,i] >= Pmin[j])
            # model.c.add(model.PG[j] + model.RG[j,i] <= Pmax[j])
            model.c.add(model.PG[j] >= Pmin[j])
            model.c.add(model.PG[j] <= Pmax[j])
            # Reserve capacity limit
            # model.c.add(model.RG[j,i] >= -model.RG_down[j])
            # model.c.add(model.RG[j,i] <= model.RG_up[j])
    
        # DC Power flow constraint
        for j in range(NB):
            ### Add PC RL
            model.c.add(sum(CG[j,k]*model.PG[k] for k in range(NG))\
                - sum(CL[j,k]*PL[k] for k in range(NL)) == sum(B[j,k]*model.Va[k] for k in range(NB)))
            # model.c.add(sum(CG[j,k]*model.PG[k] + CG[j,k]*model.RG[k,i] for k in range(NG)) + CW[j]*PW_sample[i]\
            # - sum(CL[j,k]*PL[k] for k in range(NL)) >= sum(B[j,k]*model.Va[k] for k in range(NB)) - model.s1[i])
            # model.c.add(sum(CG[j,k]*model.PG[k] + CG[j,k]*model.RG[k,i] for k in range(NG)) + CW[j]*PW_sample[i]\
            # - sum(CL[j,k]*PL[k] for k in range(NL)) <= sum(B[j,k]*model.Va[k] for k in range(NB)) + model.s2[i])

        
        # P_mis_wind = PW_sample[i] - PW_f

        # P_mis_load = 0
        # for j in range(NL):
        #     identified_VS = VS(0.25,Tamb_sample[j],num_TCL,Tset[:,j],delta,R[:,j],C[:,j],P_el[:,j],COP[:,j],baseMVA)
        #     P_mis_load = P_mis_load + (model.PC[j] - identified_VS[0])
        # P_mis = P_mis_wind - P_mis_load
        
        # P_mis = P_mis_wind
        # d = max(-P_mis, 0)
        # e = max(P_mis, 0)
        
        # model.c.add(model.RG[i] == model.dG_up[i]*max(-model.P_mis,0) - model.dG_down[i]*max(model.P_mis,0))
        # for j in range(NG):
            # model.c.add(model.RG[j] == model.dG_up[j]*model.a[2*i] - model.dG_down[j]*model.a[2*i+1])
            # model.c.add(model.RG[j,i] == model.dG_up[j]*d - model.dG_down[j]*e)
            # model.c.add(model.a[2*i+1] <= model.y[2*i+1]*P_mis[i])
            # model.c.add(model.a[2*i] <= -model.y[2*i]*P_mis[i])
        

    # for j in range(NL):
    #     # model.c.add(model.RL[j] == model.dL_up[j]*max(model.P_mis,0) - model.dL_down[j]*max(-model.P_mis,0))
    #     model.c.add(model.RL[j] == model.dL_up[j]*P_mis - model.dL_down[j]*(-P_mis))
    #     identified_VS = VS(0.25,Tamb_sample[j],num_TCL,Tset[:,j],delta,R[:,j],C[:,j],P_el[:,j],COP[:,j],baseMVA)
    #     model.c.add(model.PC[i] + model.RL[i] >= identified_VS[1])
    #     model.c.add(model.PC[i] + model.RL[i] <= identified_VS[2])
    #     model.c.add(model.RL[i] >= -model.RL_down[i])
    #     model.c.add(model.RL[i] <= model.RL_up[i])
    #     model.c.add(S0[j] + 0.25*(model.PC[i] + model.RL[i] - identified_VS[0])*1000*baseMVA >= identified_VS[3])
    #     model.c.add(S0[j] + 0.25*(model.PC[i] + model.RL[i] - identified_VS[0])*1000*baseMVA  <= identified_VS[4])
    #     model.c.add(S0[j] + 0.75*(model.PC[i] - identified_VS[0])*1000*baseMVA  + 0.25*(model.PC[i] + model.RL[i] - identified_VS[0])*1000*baseMVA  >= identified_VS[3])
    #     model.c.add(S0[j] + 0.75*(model.PC[i] - identified_VS[0])*1000*baseMVA  + 0.25*(model.PC[i] + model.RL[i] - identified_VS[0])*1000*baseMVA  <= identified_VS[4])         
    
    def cost(model, CG0, CG1, CG2, CRG_down, CRG_up, nsample, CRL_down, CRL_up):
        # cost = sum(CG0[i] for i in range(NG))\
        #     + sum(CG1[i]*model.PG[i] for i in range(NG))\
        #     + sum(CG2[i]*model.PG[i]**2 for i in range(NG))\
        #     + sum(CRG_up[i]*model.RG_up[i] for i in range(NG))\
        #     + sum(CRG_down[i]*model.RG_down[i] for i in range(NG))\
        #     + sum(CRL_up[i]*model.RL_up[i] for i in range(NL))\
        #     + sum(CRL_down[i]*model.RL_down[i] for i in range(NL))  
        cost = sum(CG0[i] for i in range(NG))\
                + sum(CG1[i]*model.PG[i] for i in range(NG))\
                + sum(CG2[i]*model.PG[i]**2 for i in range(NG))
                # + sum(CRG_up[i]*model.RG_up[i] for i in range(NG))\
                # + sum(CRG_down[i]*model.RG_down[i] for i in range(NG))\
                # + 1000*sum(model.s1[i] + model.s2[i] for i in range(nsample))
                
        # + sum(CRL_up[i]*model.RL_up[i] for i in range(NL))\
        # + sum(CRL_down[i]*model.RL_down[i] for i in range(NL))  
        return cost

    model.obj = Objective(expr=cost(model, CG0, CG1, CG2, CRG_down, CRG_up, nsample, CRL_down, CRL_up), sense=minimize)

    
    return model

# %%
# Parameters related to the demand side
num_TCL = 3000
Tset = np.zeros((num_TCL,NL))
R = np.zeros((num_TCL,NL))
C = np.zeros((num_TCL,NL))
COP = np.zeros((num_TCL,NL))
P_el = np.zeros((num_TCL,NL))
Tset_set = [21,21.5,22,22.5,23]
for i in range(num_TCL): 
    for j in range(NL):
        s = random.sample(Tset_set,1)
        Tset[i,j] = s[0] 
delta = 1
R_nom = 2
R_low = 0.8*R_nom
R_high = 1.2*R_nom
C_nom = 2
C_low = 0.8*C_nom
C_high = 1.2*C_nom
COP_nom = 2.5
COP_low = 0.8*COP_nom
COP_high = 1.2*COP_nom
for i in range(NL): 
    R[:,i] = np.random.uniform(R_low,R_high,num_TCL)
    C[:,i] = np.random.uniform(C_low,C_high,num_TCL)
    COP[:,i] = np.random.uniform(COP_low,COP_high,num_TCL)
    for j in range(num_TCL):
        P_el[j,i] = np.ceil((Tset[j,i] + delta/2 - Tamb_min)/(R[j,i]*COP[j,i])) + 1
# Sampling
eps = 0.1
beta = 0.1
num_decision_variables = 5*NG + 5*NL
num_samples = np.ceil((2/eps)*(np.log(1/beta) + num_decision_variables)).astype(int)
i = 0
mu_Tamb = Tamb[i]
sigma_Tamb = std_Tamb[i] 

np.random.seed(1)
Tamb_sample = np.random.normal(mu_Tamb,sigma_Tamb,num_samples)
PW_sample = np.random.choice(PW_data[i,:], size=num_samples)

P_B = np.zeros((NL,1))
Pdown = np.zeros((NL,1))
Pup = np.zeros((NL,1))
Sdown = np.zeros((NL,1))
Sup = np.zeros((NL,1))
S0 = np.zeros((NL,1))

for j in range(NL):
    [P_B[j],Pdown[j],Pup[j],Sdown[j],Sup[j]] = \
        VS(0.25,Tamb[i],num_TCL,Tset[:,j],delta,R[:,j],C[:,j],P_el[:,j],COP[:,j],baseMVA)
    S0[j] = (Sdown[j] + Sup[j])/2

# %%
# Define the model
nsample= 1
# Pmax = 10*Pmax
PW_f = np.median(PW_data)
model = optimizer(NG,NL,Tamb_sample,PW_sample,PW_data,num_TCL,Tset,delta,R,C,P_el,COP,S0,PL,\
    Pmax,Pmin,Lmax,Lmin,CG,CW,CL,CG0,CG1,CG2,CW0,CW1,CRG_up,CRG_down,CRL_up,CRL_down,nsample,PW_f)

# %%
# Solve the problem
solver = SolverFactory("bonmin")
solver.solve(model)

model.display()
# Out:
# Model unknown
#
#   Variables:
#     PG : Size=10, Index=PG_index
#         Key : Lower : Value              : Upper : Fixed : Stale : Domain
#           0 :     0 :  6.608459941000233 :  None : False : False : NonNegativeReals
#           1 :     0 :  6.460000064599663 :  None : False : False : NonNegativeReals
#           2 :     0 :  6.608459941000192 :  None : False : False : NonNegativeReals
#           3 :     0 :  6.520000065199435 :  None : False : False : NonNegativeReals
#           4 :     0 :  5.080000050799967 :  None : False : False : NonNegativeReals
#           5 :     0 :  6.608459941000068 :  None : False : False : NonNegativeReals
#           6 :     0 :  5.800000057999938 :  None : False : False : NonNegativeReals
#           7 :     0 :  5.640000056399948 :  None : False : False : NonNegativeReals
#           8 :     0 : 6.6084599410002465 :  None : False : False : NonNegativeReals
#           9 :     0 :   6.60845994100031 :  None : False : False : NonNegativeReals
#     Va : Size=39, Index=Va_index
#         Key : Lower : Value                 : Upper : Fixed : Stale : Domain
#           0 :    -1 :   -0.1327754642806673 :     1 : False : False :  Reals
#           1 :    -1 :  0.024671596272499402 :     1 : False : False :  Reals
#           2 :    -1 :  -0.04340108180809893 :     1 : False : False :  Reals
#           3 :    -1 :  -0.07174155580124031 :     1 : False : False :  Reals
#           4 :    -1 :  -0.05902809960026357 :     1 : False : False :  Reals
#           5 :    -1 :  -0.04574245893094485 :     1 : False : False :  Reals
#           6 :    -1 :  -0.09250687133591312 :     1 : False : False :  Reals
#           7 :    -1 :  -0.10513427753839724 :     1 : False : False :  Reals
#           8 :    -1 :  -0.16472839900174166 :     1 : False : False :  Reals
#           9 :    -1 :  0.002036072116914492 :     1 : False : False :  Reals
#          10 :    -1 :  -0.01437786863426882 :     1 : False : False :  Reals
#          11 :    -1 : -0.014038523406235917 :     1 : False : False :  Reals
#          12 :    -1 : -0.009966364878203016 :     1 : False : False :  Reals
#          13 :    -1 : -0.037218284916886925 :     1 : False : False :  Reals
#          14 :    -1 :  -0.03769541053439441 :     1 : False : False :  Reals
#          15 :    -1 : -0.007822091677462159 :     1 : False : False :  Reals
#          16 :    -1 : -0.029533174166201867 :     1 : False : False :  Reals
#          17 :    -1 : -0.042836971499390517 :     1 : False : False :  Reals
#          18 :    -1 :   0.08577791058452612 :     1 : False : False :  Reals
#          19 :    -1 :   0.06061775132762805 :     1 : False : False :  Reals
#          20 :    -1 :   0.03973638840973609 :     1 : False : False :  Reals
#          21 :    -1 :    0.1274162936853491 :     1 : False : False :  Reals
#          22 :    -1 :   0.12409844186931163 :     1 : False : False :  Reals
#          23 :    -1 : -0.004372894906656162 :     1 : False : False :  Reals
#          24 :    -1 :  0.039553837440928497 :     1 : False : False :  Reals
#          25 :    -1 : -0.014371235341224774 :     1 : False : False :  Reals
#          26 :    -1 :  -0.04366784786394861 :     1 : False : False :  Reals
#          27 :    -1 :  0.014442370060481075 :     1 : False : False :  Reals
#          28 :    -1 :   0.05472738781503294 :     1 : False : False :  Reals
#          29 :    -1 :   0.14727504932790625 :     1 : False : False :  Reals
#          30 :    -1 :   0.12460154279709615 :     1 : False : False :  Reals
#          31 :    -1 :    0.1434571148543186 :     1 : False : False :  Reals
#          32 :    -1 :   0.18484279157516634 :     1 : False : False :  Reals
#          33 :    -1 :     0.152880712250257 :     1 : False : False :  Reals
#          34 :    -1 :   0.22427979527055758 :     1 : False : False :  Reals
#          35 :    -1 :    0.2818584434469099 :     1 : False : False :  Reals
#          36 :    -1 :   0.17367303878211923 :     1 : False : False :  Reals
#          37 :    -1 :   0.16039666227162688 :     1 : False : False :  Reals
#          38 :    -1 :  -0.20414618237870058 :     1 : False : False :  Reals
#
#   Objectives:
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 41263.940746896915
#
#   Constraints:
#     c : Size=151
#         Key : Lower                : Body                    : Upper
#           1 :                 None :     -3.8308287239213312 :                  6.0
#           2 :                 -6.0 :     -3.8308287239213312 :                 None
#           3 :                 None :      2.8548287239213304 :                 10.0
#           4 :                -10.0 :      2.8548287239213304 :                 None
#           5 :                 None :       4.508124376198564 :                  5.0
#           6 :                 -5.0 :       4.508124376198564 :                 None
#           7 :                 None :      -1.730493159119662 :                  5.0
#           8 :                 -5.0 :      -1.730493159119662 :                 None
#           9 :                 None :      -6.608459941000233 :                  9.0
#          10 :                 -9.0 :      -6.608459941000233 :                 None
#          11 :                 None :      1.3305386851240084 :                  5.0
#          12 :                 -5.0 :      1.3305386851240084 :                 None
#          13 :                 None :    -0.04241430892544473 :                  5.0
#          14 :                 -5.0 :    -0.04241430892544473 :                 None
#          15 :                 None :     -0.9932387657013075 :                  6.0
#          16 :                 -6.0 :     -0.9932387657013075 :                 None
#          17 :                 None :     -2.6762225491746805 :                  5.0
#          18 :                 -5.0 :     -2.6762225491746805 :                 None
#          19 :                 None :      -5.109861795891817 :                 12.0
#          20 :                -12.0 :      -5.109861795891817 :                 None
#          21 :                 None :       4.116623030190507 :                  9.0
#          22 :                 -9.0 :       4.116623030190507 :                 None
#          23 :                 None :       5.083088304887856 :                  9.0
#          24 :                 -9.0 :       5.083088304887856 :                 None
#          25 :                 None :     -3.8249500361800033 :                  4.8
#          26 :                 -4.8 :     -3.8249500361800033 :                 None
#          27 :                 None :      -6.368000064599663 :                 18.0
#          28 :                -18.0 :      -6.368000064599663 :                 None
#          29 :                 None :       2.745088304887851 :                  9.0
#          30 :                 -9.0 :       2.745088304887851 :                 None
#          31 :                 None :      1.6417113350783583 :                  9.0
#          32 :                 -9.0 :      1.6417113350783583 :                 None
#          33 :                 None :      1.5767113350783566 :                  9.0
#          34 :                 -9.0 :      1.5767113350783566 :                 None
#          35 :                 None :      3.8171955235310024 :                  6.0
#          36 :                 -6.0 :      3.8171955235310024 :                 None
#          37 :                 None :      2.7912644174691876 :                  6.0
#          38 :                 -6.0 :      2.7912644174691876 :                 None
#          39 :                 None :      -6.608459941000192 :                  9.0
#          40 :                 -9.0 :      -6.608459941000192 :                 None
#          41 :                 None :    0.007754512649000289 :                  5.0
#          42 :                 -5.0 :    0.007754512649000289 :                 None
#          43 :                 None :     -0.0930545126490003 :                  5.0
#          44 :                 -5.0 :     -0.0930545126490003 :                 None
#          45 :                 None :      2.6982099048201893 :                  6.0
#          46 :                 -6.0 :      2.6982099048201893 :                 None
#          47 :                 None :    0.021987355645506135 :                  6.0
#          48 :                 -6.0 :    0.021987355645506135 :                 None
#          49 :                 None :     -3.1780126443544945 :                  6.0
#          50 :                 -6.0 :     -3.1780126443544945 :                 None
#          51 :                 None :      2.4394474706449114 :                  6.0
#          52 :                 -6.0 :      2.4394474706449114 :                 None
#          53 :                 None :      -4.800000115999399 :                  6.0
#          54 :                 -6.0 :      -4.800000115999399 :                 None
#          55 :                 None :        -3.5228503768295 :                  6.0
#          56 :                 -6.0 :        -3.5228503768295 :                 None
#          57 :                 None :      -0.584609622170508 :                  6.0
#          58 :                 -6.0 :      -0.584609622170508 :                 None
#          59 :                 None :      1.6224143089254448 :                  6.0
#          60 :                 -6.0 :      1.6224143089254448 :                 None
#          61 :                 None :       0.817033161719465 :                  6.0
#          62 :                 -6.0 :       0.817033161719465 :                 None
#          63 :                 None :       1.719999949200032 :                  9.0
#          64 :                 -9.0 :       1.719999949200032 :                 None
#          65 :                 None :      -6.520000065199434 :                  9.0
#          66 :                 -9.0 :      -6.520000065199434 :                 None
#          67 :                 None :      -5.080000050799967 :                  9.0
#          68 :                 -9.0 :      -5.080000050799967 :                 None
#          69 :                 None :        -6.2628503768295 :                  9.0
#          70 :                 -9.0 :        -6.2628503768295 :                 None
#          71 :                 None :      0.3456095641705694 :                  6.0
#          72 :                 -6.0 :      0.3456095641705694 :                 None
#          73 :                 None :      -6.608459941000069 :                  9.0
#          74 :                 -9.0 :      -6.608459941000069 :                 None
#          75 :                 None :      3.6706096221705082 :                  6.0
#          76 :                 -6.0 :      3.6706096221705082 :                 None
#          77 :                 None :      -5.800000057999937 :                  9.0
#          78 :                 -9.0 :      -5.800000057999937 :                 None
#          79 :                 None :       1.669506897280287 :                  6.0
#          80 :                 -6.0 :       1.669506897280287 :                 None
#          81 :                 None :     -5.6400000563999475 :                  9.0
#          82 :                 -9.0 :     -5.6400000563999475 :                 None
#          83 :                 None :      1.9929668382805334 :                  6.0
#          84 :                 -6.0 :      1.9929668382805334 :                 None
#          85 :                 None :     -0.6078819705001234 :                  6.0
#          86 :                 -6.0 :     -0.6078819705001234 :                 None
#          87 :                 None :     -1.1055779705001234 :                  6.0
#          88 :                 -6.0 :     -1.1055779705001234 :                 None
#          89 :                 None :     -2.6678819705001233 :                  6.0
#          90 :                 -6.0 :     -2.6678819705001233 :                 None
#          91 :                 None :     -6.6084599410002465 :                 12.0
#          92 :                -12.0 :     -6.6084599410002465 :                 None
#          93 :                  0.0 :       6.608459941000233 :                 None
#          94 :                 None :       6.608459941000233 :                 10.4
#          95 :                  0.0 :       6.460000064599663 :                 None
#          96 :                 None :       6.460000064599663 :                 6.46
#          97 :                  0.0 :       6.608459941000192 :                 None
#          98 :                 None :       6.608459941000192 :                 7.25
#          99 :                  0.0 :       6.520000065199435 :                 None
#         100 :                 None :       6.520000065199435 :                 6.52
#         101 :                  0.0 :       5.080000050799967 :                 None
#         102 :                 None :       5.080000050799967 :                 5.08
#         103 :                  0.0 :       6.608459941000068 :                 None
#         104 :                 None :       6.608459941000068 :                 6.87
#         105 :                  0.0 :       5.800000057999938 :                 None
#         106 :                 None :       5.800000057999938 :                  5.8
#         107 :                  0.0 :       5.640000056399948 :                 None
#         108 :                 None :       5.640000056399948 :                 5.64
#         109 :                  0.0 :      6.6084599410002465 :                 None
#         110 :                 None :      6.6084599410002465 :                 8.65
#         111 :                  0.0 :        6.60845994100031 :                 None
#         112 :                 None :        6.60845994100031 :                 11.0
#         113 :               -0.976 :     -0.9760000000000009 :               -0.976
#         114 :                  0.0 :  -8.881784197001252e-16 :                  0.0
#         115 :                -3.22 :     -3.2199999999999998 :                -3.22
#         116 :                 -5.0 :     -4.9999999999999964 :                 -5.0
#         117 :                  0.0 :  -7.105427357601002e-15 :                  0.0
#         118 :                  0.0 :   4.440892098500626e-15 :                  0.0
#         119 :               -2.338 :      -2.338000000000001 :               -2.338
#         120 :                -5.22 :      -5.220000000000001 :                -5.22
#         121 :               -0.065 :    -0.06500000000000128 :               -0.065
#         122 :                  0.0 : -1.7763568394002505e-15 :                  0.0
#         123 :                  0.0 :   5.551115123125783e-16 :                  0.0
#         124 : -0.08529999999999999 :    -0.08530000000000001 : -0.08529999999999999
#         125 :                  0.0 :   2.220446049250313e-15 :                  0.0
#         126 :                  0.0 : -2.4424906541753444e-15 :                  0.0
#         127 :                 -3.2 :     -3.2000000000000015 :                 -3.2
#         128 :                -3.29 :     -3.2900000000000014 :                -3.29
#         129 :                  0.0 :  -8.881784197001252e-16 :                  0.0
#         130 :                -1.58 :                   -1.58 :                -1.58
#         131 :                  0.0 :                     0.0 :                  0.0
#         132 :                 -6.8 :                    -6.8 :                 -6.8
#         133 :                -2.74 :     -2.7399999999999993 :                -2.74
#         134 :                  0.0 :                     0.0 :                  0.0
#         135 :               -2.475 :     -2.4749999999999996 :               -2.475
#         136 :  -3.0860000000000003 :                  -3.086 :  -3.0860000000000003
#         137 :                -2.24 :     -2.2399999999999993 :                -2.24
#         138 :                -1.39 :     -1.3900000000000001 :                -1.39
#         139 :                -2.81 :     -2.8099999999999987 :                -2.81
#         140 :                -2.06 :                   -2.06 :                -2.06
#         141 :               -2.835 :      -2.835000000000001 :               -2.835
#         142 :                  0.0 :                     0.0 :                  0.0
#         143 :                  0.0 :   8.881784197001252e-16 :                  0.0
#         144 :                  0.0 :                     0.0 :                  0.0
#         145 :                  0.0 :   8.881784197001252e-16 :                  0.0
#         146 :                  0.0 :                     0.0 :                  0.0
#         147 :                  0.0 :  -8.881784197001252e-16 :                  0.0
#         148 :                  0.0 :   8.881784197001252e-16 :                  0.0
#         149 :                  0.0 :   8.881784197001252e-16 :                  0.0
#         150 :                  0.0 :                     0.0 :                  0.0
#         151 :                  0.0 : -1.7763568394002505e-15 :                  0.0

# %%
model.obj()
# Out:
# 41263.940746896915

# %%
# Print generation, cost and marginal cost
r_pg = np.zeros((NG,1))
r_cost = np.zeros((NG,1))
r_mc = np.zeros((NG,1))
for i in range(NG):
    r_pg[i] = model.PG[i]()
    r_cost[i] = CG0[i] + CG1[i]*r_pg[i] + CG2[i]*r_pg[i]**2
    r_mc[i] = CG1[i] + CG2[i]*r_pg[i]

print(r_pg*baseMVA)
print(r_cost)
print(r_mc)
# Out:
# [[660.8459941 ]
#  [646.00000646]
#  [660.8459941 ]
#  [652.00000652]
#  [508.00000508]
#  [660.8459941 ]
#  [580.0000058 ]
#  [564.00000564]
#  [660.8459941 ]
#  [660.8459941 ]]
# [[4565.62807741]
#  [4367.1600854 ]
#  [4565.62807741]
#  [4446.84008698]
#  [2733.24005314]
#  [4565.62807741]
#  [3538.20006902]
#  [3350.36006531]
#  [4565.62807741]
#  [4565.62807741]]
# [[690.8459941 ]
#  [676.00000646]
#  [690.8459941 ]
#  [682.00000652]
#  [538.00000508]
#  [690.8459941 ]
#  [610.0000058 ]
#  [594.00000564]
#  [690.8459941 ]
#  [690.8459941 ]]

# %%
Pmax
# Out:
# array([10.4 ,  6.46,  7.25,  6.52,  5.08,  6.87,  5.8 ,  5.64,  8.65,
#        11.  ])

# %%
model.PG.pprint()
# Out:
# PG : Size=10, Index=PG_index
#     Key : Lower : Value              : Upper : Fixed : Stale : Domain
#       0 :     0 :  6.608459941000233 :  None : False : False : NonNegativeReals
#       1 :     0 :  6.460000064599663 :  None : False : False : NonNegativeReals
#       2 :     0 :  6.608459941000192 :  None : False : False : NonNegativeReals
#       3 :     0 :  6.520000065199435 :  None : False : False : NonNegativeReals
#       4 :     0 :  5.080000050799967 :  None : False : False : NonNegativeReals
#       5 :     0 :  6.608459941000068 :  None : False : False : NonNegativeReals
#       6 :     0 :  5.800000057999938 :  None : False : False : NonNegativeReals
#       7 :     0 :  5.640000056399948 :  None : False : False : NonNegativeReals
#       8 :     0 : 6.6084599410002465 :  None : False : False : NonNegativeReals
#       9 :     0 :   6.60845994100031 :  None : False : False : NonNegativeReals
